# %% [markdown]
# pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.
# Machine learnning - learinging  patterns from the data
#
# pandas is developed in 2008 by Mckinney
# very useful with structured data(tabular)

# %%
import pandas as pd

# %%
pd.read_csv("Copy of annual haldia report.csv") #read a comma-separated values (csv) file into dataframe.
# Out:
#         Date  Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)  \
# 0   03/01/22      156.830000   183.570000       52.270000
# 1   03/02/22      270.929286   310.823095      138.734524
# 2   03/03/22      341.769032   950.239737      441.344762
# 3   03/04/22      502.135333  1583.427146      691.952778
# 4   03/05/22      432.117419  1298.605287      613.862366
# 5   03/06/22      356.187333  1060.554114      496.920000
# 6   03/07/22      319.416129   879.429677      444.374839
# 7   03/08/22      415.629416   457.040399      212.974270
# 8   03/09/22      409.616667   200.686667       60.670000
# 9   03/10/22      299.942857   208.250000       68.357143
# 10  03/11/22      348.553333   301.583333      110.783333
# 11  03/12/22      313.691398   330.516129      117.080645
# 12  03/01/23      273.009140   389.220430      139.559140
# 13  03/02/23      432.070833   796.419643      378.523810
# 14  03/03/23      439.493637  1575.146806      827.199817
# ...

# %%
#by default pandas understand the first row as the column name
pd.read_csv("Copy of annual haldia report.csv", header  = None) #internal integer indexes are provided by pandas for rows and column
# Out:
#            0               1            2               3  \
# 0       Date  Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)
# 1   03/01/22          156.83       183.57           52.27
# 2   03/02/22     270.9292857  310.8230952     138.7345238
# 3   03/03/22     341.7690323  950.2397372     441.3447619
# 4   03/04/22     502.1353333  1583.427146     691.9527778
# 5   03/05/22     432.1174194  1298.605287     613.8623656
# 6   03/06/22     356.1873333  1060.554114          496.92
# 7   03/07/22      319.416129  879.4296774     444.3748387
# 8   03/08/22     415.6294163  457.0403994     212.9742704
# 9   03/09/22     409.6166667  200.6866667           60.67
# 10  03/10/22     299.9428571       208.25     68.35714286
# 11  03/11/22     348.5533333  301.5833333     110.7833333
# 12  03/12/22     313.6913978   330.516129     117.0806452
# 13  03/01/23     273.0091398  389.2204301     139.5591398
# 14  03/02/23     432.0708333  796.4196429     378.5238095
# ...

# %%
#if you dont want the fisrt two rows
pd.read_csv("Copy of annual haldia report.csv", skiprows = 2)#skip first two rows while reading the data
# Out:
#     03/02/22  270.9292857  310.8230952  138.7345238  629.1867857      0.36
# 0   03/03/22   341.769032   950.239737   441.344762  1924.020557  1.039793
# 1   03/04/22   502.135333  1583.427146   691.952778  3232.316660  1.772764
# 2   03/05/22   432.117419  1298.605287   613.862366  2651.396454  1.427913
# 3   03/06/22   356.187333  1060.554114   496.920000  2163.357619  1.165638
# 4   03/07/22   319.416129   879.429677   444.374839  1794.032258  0.970000
# 5   03/08/22   415.629416   457.040399   212.974270   931.845238  0.513283
# 6   03/09/22   409.616667   200.686667    60.670000   409.010000  0.245233
# 7   03/10/22   299.942857   208.250000    68.357143   424.392857  0.253214
# 8   03/11/22   348.553333   301.583333   110.783333   615.500000  0.347167
# 9   03/12/22   313.691398   330.516129   117.080645   665.424731  0.372634
# 10  03/01/23   273.009140   389.220430   139.559140   793.690860  0.437823
# ...

# %%
pd.read_csv("Copy of annual haldia report.csv", usecols = ['Date','TDS(mg/l)'])
# Out:
#         Date    TDS(mg/l)
# 0   03/01/22   183.570000
# 1   03/02/22   310.823095
# 2   03/03/22   950.239737
# 3   03/04/22  1583.427146
# 4   03/05/22  1298.605287
# 5   03/06/22  1060.554114
# 6   03/07/22   879.429677
# 7   03/08/22   457.040399
# 8   03/09/22   200.686667
# 9   03/10/22   208.250000
# 10  03/11/22   301.583333
# 11  03/12/22   330.516129
# 12  03/01/23   389.220430
# 13  03/02/23   796.419643
# 14  03/03/23  1575.146806
# 15  03/04/23  1671.016855
# 16  03/05/23  1857.135165
# 17  03/06/23  1463.191419
# 18  03/07/23   792.983781
# 19  03/08/23   496.696111
# 20  03/09/23   295.003333
# 21  03/10/23   171.108602
# 22  03/11/23   312.272778
# 23  03/12/23   261.333871
# 24  03/01/24   325.390323
# 25  03/02/24   577.243908
# 26  03/03/24  1566.491039
# 27  03/04/24  2051.474259
# 28  03/05/24  2309.939337
# 29  03/06/24  1313.651786
# 30  03/07/24   690.112865
# 31  03/08/24   159.844355
# 32  03/09/24   129.110000
# 33  03/10/24   140.820000
# ...

# %%
df = pd.read_csv('Copy of annual haldia report.csv')

# %%
df
# Out:
#         Date  Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)  \
# 0   03/01/22      156.830000   183.570000       52.270000
# 1   03/02/22      270.929286   310.823095      138.734524
# 2   03/03/22      341.769032   950.239737      441.344762
# 3   03/04/22      502.135333  1583.427146      691.952778
# 4   03/05/22      432.117419  1298.605287      613.862366
# 5   03/06/22      356.187333  1060.554114      496.920000
# 6   03/07/22      319.416129   879.429677      444.374839
# 7   03/08/22      415.629416   457.040399      212.974270
# 8   03/09/22      409.616667   200.686667       60.670000
# 9   03/10/22      299.942857   208.250000       68.357143
# 10  03/11/22      348.553333   301.583333      110.783333
# 11  03/12/22      313.691398   330.516129      117.080645
# 12  03/01/23      273.009140   389.220430      139.559140
# 13  03/02/23      432.070833   796.419643      378.523810
# 14  03/03/23      439.493637  1575.146806      827.199817
# ...

# %%
#data structure >> Series and data frame
#series >> 1 dimensional in nature
#dataframe >> 2 dimesional in nature,multiple series combines to form of a dataframe()

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type([1,2,3,4])
# Out:
# list

# %%
df
# Out:
#         Date  Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)  \
# 0   03/01/22      156.830000   183.570000       52.270000
# 1   03/02/22      270.929286   310.823095      138.734524
# 2   03/03/22      341.769032   950.239737      441.344762
# 3   03/04/22      502.135333  1583.427146      691.952778
# 4   03/05/22      432.117419  1298.605287      613.862366
# 5   03/06/22      356.187333  1060.554114      496.920000
# 6   03/07/22      319.416129   879.429677      444.374839
# 7   03/08/22      415.629416   457.040399      212.974270
# 8   03/09/22      409.616667   200.686667       60.670000
# 9   03/10/22      299.942857   208.250000       68.357143
# 10  03/11/22      348.553333   301.583333      110.783333
# 11  03/12/22      313.691398   330.516129      117.080645
# 12  03/01/23      273.009140   389.220430      139.559140
# 13  03/02/23      432.070833   796.419643      378.523810
# 14  03/03/23      439.493637  1575.146806      827.199817
# ...

# %%
df.Date
# Out:
# 0     03/01/22
# 1     03/02/22
# 2     03/03/22
# 3     03/04/22
# 4     03/05/22
# 5     03/06/22
# 6     03/07/22
# 7     03/08/22
# 8     03/09/22
# 9     03/10/22
# 10    03/11/22
# 11    03/12/22
# 12    03/01/23
# 13    03/02/23
# 14    03/03/23
# 15    03/04/23
# 16    03/05/23
# 17    03/06/23
# 18    03/07/23
# 19    03/08/23
# 20    03/09/23
# 21    03/10/23
# 22    03/11/23
# 23    03/12/23
# 24    03/01/24
# 25    03/02/24
# 26    03/03/24
# 27    03/04/24
# 28    03/05/24
# 29    03/06/24
# 30    03/07/24
# 31    03/08/24
# 32    03/09/24
# 33    03/10/24
# 34    03/11/24
# 35    03/12/24
# 36    03/01/25
# 37    03/02/25
# 38    03/03/25
# 39    03/04/25
# 40    03/05/25
# 41         NaN
# 42         NaN
# Name: Date, dtype: object

# %%
df["Conductivity(ms/cm)"]
# Out:
# 0      375.370000
# 1      629.186786
# 2     1924.020557
# 3     3232.316660
# 4     2651.396454
# 5     2163.357619
# 6     1794.032258
# 7      931.845238
# 8      409.010000
# 9      424.392857
# 10     615.500000
# 11     665.424731
# 12     793.690860
# 13    1595.113095
# 14    3212.072451
# 15    3396.765229
# 16    3779.700996
# 17    2985.519922
# 18    1617.483513
# 19    1015.072222
# 20     601.281667
# 21     348.333871
# 22     636.991111
# 23     532.687634
# 24     663.364516
# 25    1177.206322
# 26    3196.351523
# 27    4185.768056
# 28    4712.534562
# 29    2665.559325
# 30    1407.579339
# 31     328.838441
# 32     268.650000
# 33     292.880000
# 34     368.730000
# 35     520.050000
# 36     557.697312
# 37    1348.583571
# 38    3685.853548
# 39    4998.816000
# 40    3584.377273
# 41            NaN
# 42            NaN
# Name: Conductivity(ms/cm), dtype: float64

# %%
type(df["Conductivity(ms/cm)"])#a column is a series in a data frame
# Out:
# pandas.core.series.Series

# %%
l = [1,2,3,4]
s= pd.Series(l)

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s[3]
# Out:
# np.int64(4)

# %%
s[1:]
# Out:
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s[2:4]
# Out:
# 2    3
# 3    4
# dtype: int64

# %%
#by default indexes are integer, we can have custom indexes
d = pd.Series([100,200,300],index = ["sangam","munmun",1])

# %%
d
# Out:
# sangam    100
# munmun    200
# 1         300
# dtype: int64

# %%
type(d)
# Out:
# pandas.core.series.Series

# %%
d["sangam"]
# Out:
# np.int64(100)

# %%
#to see all th index of series
d.index
# Out:
# Index(['sangam', 'munmun', 1], dtype='object')

# %%
#to reset index
d.reset_index(drop = True)#Generate a new DataFrame or Series with the index reset
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
pd.DataFrame(d)
# Out:
#           0
# sangam  100
# munmun  200
# 1       300

# %%
df
# Out:
#         Date  Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)  \
# 0   03/01/22      156.830000   183.570000       52.270000
# 1   03/02/22      270.929286   310.823095      138.734524
# 2   03/03/22      341.769032   950.239737      441.344762
# 3   03/04/22      502.135333  1583.427146      691.952778
# 4   03/05/22      432.117419  1298.605287      613.862366
# 5   03/06/22      356.187333  1060.554114      496.920000
# 6   03/07/22      319.416129   879.429677      444.374839
# 7   03/08/22      415.629416   457.040399      212.974270
# 8   03/09/22      409.616667   200.686667       60.670000
# 9   03/10/22      299.942857   208.250000       68.357143
# 10  03/11/22      348.553333   301.583333      110.783333
# 11  03/12/22      313.691398   330.516129      117.080645
# 12  03/01/23      273.009140   389.220430      139.559140
# 13  03/02/23      432.070833   796.419643      378.523810
# 14  03/03/23      439.493637  1575.146806      827.199817
# ...

# %%
df.head(5)
# Out:
#        Date  Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)  Conductivity(ms/cm)  \
# 0  03/01/22      156.830000   183.570000       52.270000           375.370000
# 1  03/02/22      270.929286   310.823095      138.734524           629.186786
# 2  03/03/22      341.769032   950.239737      441.344762          1924.020557
# 3  03/04/22      502.135333  1583.427146      691.952778          3232.316660
# 4  03/05/22      432.117419  1298.605287      613.862366          2651.396454
#
#    Salinity (%)
# 0      0.220000
# 1      0.360000
# 2      1.039793
# 3      1.772764
# 4      1.427913

# %%
df.head(2)
# Out:
#        Date  Turbidity(NTU)   TDS(mg/l)  Chloride(mg/L)  Conductivity(ms/cm)  \
# 0  03/01/22      156.830000  183.570000       52.270000           375.370000
# 1  03/02/22      270.929286  310.823095      138.734524           629.186786
#
#    Salinity (%)
# 0          0.22
# 1          0.36

# %%
df.tail(5)
# Out:
#         Date  Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)  \
# 38  03/03/25      364.491290  2030.813871      966.401936
# 39  03/04/25      328.093000  2798.267333     1345.957667
# 40  03/05/25      242.210968  1973.634091      949.288182
# 41       NaN             NaN          NaN             NaN
# 42       NaN             NaN          NaN             NaN
#
#     Conductivity(ms/cm)  Salinity (%)
# 38          3685.853548      2.082190
# 39          4998.816000      2.866310
# 40          3584.377273      1.995273
# 41                  NaN           NaN
# 42                  NaN           NaN

# %%
df.tail(2)
# Out:
#    Date  Turbidity(NTU)  TDS(mg/l)  Chloride(mg/L)  Conductivity(ms/cm)  \
# 41  NaN             NaN        NaN             NaN                  NaN
# 42  NaN             NaN        NaN             NaN                  NaN
#
#     Salinity (%)
# 41           NaN
# 42           NaN

# %%
df.shape
# Out:
# (43, 6)

# %%
df.columns
# Out:
# Index(['Date', 'Turbidity(NTU)', 'TDS(mg/l)', 'Chloride(mg/L)',
#        'Conductivity(ms/cm)', 'Salinity (%)'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Date',
#  'Turbidity(NTU)',
#  'TDS(mg/l)',
#  'Chloride(mg/L)',
#  'Conductivity(ms/cm)',
#  'Salinity (%)']

# %%
df.sample(2)#random sample
# Out:
#        Date  Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)  Conductivity(ms/cm)  \
# 4  03/05/22      432.117419  1298.605287      613.862366          2651.396454
# 8  03/09/22      409.616667   200.686667       60.670000           409.010000
#
#    Salinity (%)
# 4      1.427913
# 8      0.245233

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 41 non-null     object
#  1   Turbidity(NTU)       41 non-null     float64
#  2   TDS(mg/l)            41 non-null     float64
#  3   Chloride(mg/L)       41 non-null     float64
#  4   Conductivity(ms/cm)  41 non-null     float64
#  5   Salinity (%)         41 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 2.1+ KB

# %%
df.dtypes
# Out:
# Date                    object
# Turbidity(NTU)         float64
# TDS(mg/l)              float64
# Chloride(mg/L)         float64
# Conductivity(ms/cm)    float64
# Salinity (%)           float64
# dtype: object

# %%
df["Date"]
# Out:
# 0     03/01/22
# 1     03/02/22
# 2     03/03/22
# 3     03/04/22
# 4     03/05/22
# 5     03/06/22
# 6     03/07/22
# 7     03/08/22
# 8     03/09/22
# 9     03/10/22
# 10    03/11/22
# 11    03/12/22
# 12    03/01/23
# 13    03/02/23
# 14    03/03/23
# 15    03/04/23
# 16    03/05/23
# 17    03/06/23
# 18    03/07/23
# 19    03/08/23
# 20    03/09/23
# 21    03/10/23
# 22    03/11/23
# 23    03/12/23
# 24    03/01/24
# 25    03/02/24
# 26    03/03/24
# 27    03/04/24
# 28    03/05/24
# 29    03/06/24
# 30    03/07/24
# 31    03/08/24
# 32    03/09/24
# 33    03/10/24
# 34    03/11/24
# 35    03/12/24
# 36    03/01/25
# 37    03/02/25
# 38    03/03/25
# 39    03/04/25
# 40    03/05/25
# 41         NaN
# 42         NaN
# Name: Date, dtype: object

# %%
df["TDS(mg/l)"]
# Out:
# 0      183.570000
# 1      310.823095
# 2      950.239737
# 3     1583.427146
# 4     1298.605287
# 5     1060.554114
# 6      879.429677
# 7      457.040399
# 8      200.686667
# 9      208.250000
# 10     301.583333
# 11     330.516129
# 12     389.220430
# 13     796.419643
# 14    1575.146806
# 15    1671.016855
# 16    1857.135165
# 17    1463.191419
# 18     792.983781
# 19     496.696111
# 20     295.003333
# 21     171.108602
# 22     312.272778
# 23     261.333871
# 24     325.390323
# 25     577.243908
# 26    1566.491039
# 27    2051.474259
# 28    2309.939337
# 29    1313.651786
# 30     690.112865
# 31     159.844355
# 32     129.110000
# 33     140.820000
# 34     178.300000
# 35     255.540000
# 36     286.746237
# 37     703.790000
# 38    2030.813871
# 39    2798.267333
# 40    1973.634091
# 41            NaN
# 42            NaN
# Name: TDS(mg/l), dtype: float64

# %%
list(df["TDS(mg/l)"])
# Out:
# [183.57,
#  310.8230952,
#  950.2397372,
#  1583.427146,
#  1298.605287,
#  1060.554114,
#  879.4296774,
#  457.0403994,
#  200.6866667,
#  208.25,
#  301.5833333,
#  330.516129,
#  389.2204301,
#  796.4196429,
#  1575.146806,
#  1671.016855,
#  1857.135165,
#  1463.191419,
#  792.9837814,
#  496.6961111,
#  295.0033333,
#  171.1086022,
#  312.2727778,
#  261.333871,
#  325.3903226,
#  577.243908,
#  1566.491039,
#  2051.474259,
#  2309.939337,
#  1313.651786,
#  690.1128648,
#  159.8443548,
#  129.11,
#  140.82,
#  178.3,
#  255.54,
#  286.7462366,
#  703.79,
#  2030.813871,
#  2798.267333,
#  1973.634091,
#  nan,
#  nan]

# %%
#series to a dataframe
s = pd.Series([2,3,4], index = [100,"sangam",200])

# %%
s
# Out:
# 100       2
# sangam    3
# 200       4
# dtype: int64

# %%
d = pd.DataFrame(s)

# %%
d
# Out:
#         0
# 100     2
# sangam  3
# 200     4

# %%
type(d)
# Out:
# pandas.core.frame.DataFrame

# %%
d["new column"] = "SANGAM"

# %%
d
# Out:
#         0 new column
# 100     2     SANGAM
# sangam  3     SANGAM
# 200     4     SANGAM

# %%
d["new column"] #best way to access the column this way but its a continuous string, you can access using df.column
# Out:
# 100       SANGAM
# sangam    SANGAM
# 200       SANGAM
# Name: new column, dtype: object

# %%
d
# Out:
#         0 new column
# 100     2     SANGAM
# sangam  3     SANGAM
# 200     4     SANGAM

# %%
d["new column 2"]= [1,2,3] #no of new column elements equals to no of rows

# %%
d
# Out:
#         0 new column  new column 2
# 100     2     SANGAM             1
# sangam  3     SANGAM             2
# 200     4     SANGAM             3

# %%
#reset_index

# %%
d.reset_index(drop = True)
# Out:
#    0 new column  new column 2
# 0  2     SANGAM             1
# 1  3     SANGAM             2
# 2  4     SANGAM             3

# %%
d.columns = ["col1","col2","col3"]
d
# Out:
#         col1    col2  col3
# 100        2  SANGAM     1
# sangam     3  SANGAM     2
# 200        4  SANGAM     3

# %%
df
# Out:
#         Date  Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)  \
# 0   03/01/22      156.830000   183.570000       52.270000
# 1   03/02/22      270.929286   310.823095      138.734524
# 2   03/03/22      341.769032   950.239737      441.344762
# 3   03/04/22      502.135333  1583.427146      691.952778
# 4   03/05/22      432.117419  1298.605287      613.862366
# 5   03/06/22      356.187333  1060.554114      496.920000
# 6   03/07/22      319.416129   879.429677      444.374839
# 7   03/08/22      415.629416   457.040399      212.974270
# 8   03/09/22      409.616667   200.686667       60.670000
# 9   03/10/22      299.942857   208.250000       68.357143
# 10  03/11/22      348.553333   301.583333      110.783333
# 11  03/12/22      313.691398   330.516129      117.080645
# 12  03/01/23      273.009140   389.220430      139.559140
# 13  03/02/23      432.070833   796.419643      378.523810
# 14  03/03/23      439.493637  1575.146806      827.199817
# ...

# %%
#accessing one column --> series multiple columns (with square bracket becomes a dataframe)
#a subset of data frame
df[["Date","Salinity (%)"]]
# Out:
#         Date  Salinity (%)
# 0   03/01/22      0.220000
# 1   03/02/22      0.360000
# 2   03/03/22      1.039793
# 3   03/04/22      1.772764
# 4   03/05/22      1.427913
# 5   03/06/22      1.165638
# 6   03/07/22      0.970000
# 7   03/08/22      0.513283
# 8   03/09/22      0.245233
# 9   03/10/22      0.253214
# 10  03/11/22      0.347167
# 11  03/12/22      0.372634
# 12  03/01/23      0.437823
# 13  03/02/23      0.876845
# 14  03/03/23      1.744344
# 15  03/04/23      1.849917
# 16  03/05/23      2.058037
# 17  03/06/23      1.591691
# 18  03/07/23      0.870935
# 19  03/08/23      0.559811
# 20  03/09/23      0.342900
# 21  03/10/23      0.218446
# 22  03/11/23      0.360728
# 23  03/12/23      0.306253
# 24  03/01/24      0.371113
# 25  03/02/24      0.636259
# 26  03/03/24      1.740796
# 27  03/04/24      2.285636
# 28  03/05/24      2.584080
# 29  03/06/24      1.449637
# 30  03/07/24      0.762670
# 31  03/08/24      0.183487
# 32  03/09/24      0.130000
# ...

# %%
df_subset  = df[["Date","Salinity (%)","TDS(mg/l)"]]

# %%
df_subset
# Out:
#         Date  Salinity (%)    TDS(mg/l)
# 0   03/01/22      0.220000   183.570000
# 1   03/02/22      0.360000   310.823095
# 2   03/03/22      1.039793   950.239737
# 3   03/04/22      1.772764  1583.427146
# 4   03/05/22      1.427913  1298.605287
# 5   03/06/22      1.165638  1060.554114
# 6   03/07/22      0.970000   879.429677
# 7   03/08/22      0.513283   457.040399
# 8   03/09/22      0.245233   200.686667
# 9   03/10/22      0.253214   208.250000
# 10  03/11/22      0.347167   301.583333
# 11  03/12/22      0.372634   330.516129
# 12  03/01/23      0.437823   389.220430
# 13  03/02/23      0.876845   796.419643
# 14  03/03/23      1.744344  1575.146806
# 15  03/04/23      1.849917  1671.016855
# 16  03/05/23      2.058037  1857.135165
# 17  03/06/23      1.591691  1463.191419
# 18  03/07/23      0.870935   792.983781
# 19  03/08/23      0.559811   496.696111
# 20  03/09/23      0.342900   295.003333
# 21  03/10/23      0.218446   171.108602
# ...

# %%
type(df_subset)
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = pd.read_excel("Book2.xlsx")

# %%
df
# Out:
#         Date  Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)  \
# 0   03/01/22      156.830000   183.570000       52.270000
# 1   03/02/22      270.929286   310.823095      138.734524
# 2   03/03/22      341.769032   950.239737      441.344762
# 3   03/04/22      502.135333  1583.427146      691.952778
# 4   03/05/22      432.117419  1298.605287      613.862366
# 5   03/06/22      356.187333  1060.554114      496.920000
# 6   03/07/22      319.416129   879.429677      444.374839
# 7   03/08/22      415.629416   457.040399      212.974270
# 8   03/09/22      409.616667   200.686667       60.670000
# 9   03/10/22      299.942857   208.250000       68.357143
# 10  03/11/22      348.553333   301.583333      110.783333
# 11  03/12/22      313.691398   330.516129      117.080645
# 12  03/01/23      273.009140   389.220430      139.559140
# 13  03/02/23      432.070833   796.419643      378.523810
# 14  03/03/23      439.493637  1575.146806      827.199817
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.ndim
# Out:
# 2

# %%
df1.shape
# Out:
# (18, 19)

# %%
df1.size
# Out:
# 342

# %%
df.dtypes
# Out:
# Date                    object
# Turbidity(NTU)         float64
# TDS(mg/l)              float64
# Chloride(mg/L)         float64
# Conductivity(ms/cm)    float64
# Salinity (%)           float64
# dtype: object

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
data = requests.get("https://github.com/jigyansu1703/internship/blob/main/Quality%20report%20Jan_22%20to%20Aug_24.xlsx")
# Out:
#   Cell In[83], line 1
#     pip install openpyxl
#         ^
# SyntaxError: invalid syntax

# %%
data.xlsm()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 data.xlsm()
#
# AttributeError: 'Response' object has no attribute 'xlsm'

# %%
#all do

# %%
pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
import requests
data = requests.get("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
data.html()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 data.html()
#
# AttributeError: 'Response' object has no attribute 'html'

# %%
df1.to_csv("players.csv", index = False)#write objective to a comma-separated valiues (csv) file
#to note to get the index of df, pass index = False

# %%
#read jason file from url
url = "https://api.github.com/repos/pandas-dev/pandas/issues"#this link is jason file { } {}
pd.read_json(url)

# %%
import requests
data = requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
data
# Out:
# <Response [200]>

# %%
data.json()
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61913',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61913/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61913/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61913/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61913',
#   'id': 3246261681,
#   'node_id': 'PR_kwDOAA0YD86fuvr4',
#   'number': 61913,
#   'title': 'CI: properly enable the string dtype also for custom CI builds',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
# ...

# %% [markdown]
# "ADVANCED"

# %% [raw]
# "ADVANCED"

# %%
#solving the data sets
#import pandas as pd

#df = pd.read_csv("https://github.com/jigyansu1703/internship/blob/main/Copy%20of%20annual%20haldia%20report.csv")

# %%
import requests
data = requests.get("https://github.com/jigyansu1703/internship/blob/main/Copy%20of%20annual%20haldia%20report.csv")

# %%
#pd.read_csv("data")

# %%
import pandas as pd
import certifi
import ssl
import urllib.request

url = "https://raw.githubusercontent.com/jigyansu1703/internship/main/Copy%20of%20annual%20haldia%20report.csv"
context = ssl.create_default_context(cafile=certifi.where())
response = urllib.request.urlopen(url, context=context)

df = pd.read_csv(response)
print(df)
# Out:
#         Date  Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)  \
# 0   03/01/22      156.830000   183.570000       52.270000
# 1   03/02/22      270.929286   310.823095      138.734524
# 2   03/03/22      341.769032   950.239737      441.344762
# 3   03/04/22      502.135333  1583.427146      691.952778
# 4   03/05/22      432.117419  1298.605287      613.862366
# 5   03/06/22      356.187333  1060.554114      496.920000
# 6   03/07/22      319.416129   879.429677      444.374839
# 7   03/08/22      415.629416   457.040399      212.974270
# 8   03/09/22      409.616667   200.686667       60.670000
# 9   03/10/22      299.942857   208.250000       68.357143
# 10  03/11/22      348.553333   301.583333      110.783333
# 11  03/12/22      313.691398   330.516129      117.080645
# 12  03/01/23      273.009140   389.220430      139.559140
# 13  03/02/23      432.070833   796.419643      378.523810
# 14  03/03/23      439.493637  1575.146806      827.199817
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Turbidity(NTU)', 'TDS(mg/l)', 'Chloride(mg/L)',
#        'Conductivity(ms/cm)', 'Salinity (%)'],
#       dtype='object')

# %%
df.head()
# Out:
#        Date  Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)  Conductivity(ms/cm)  \
# 0  03/01/22      156.830000   183.570000       52.270000           375.370000
# 1  03/02/22      270.929286   310.823095      138.734524           629.186786
# 2  03/03/22      341.769032   950.239737      441.344762          1924.020557
# 3  03/04/22      502.135333  1583.427146      691.952778          3232.316660
# 4  03/05/22      432.117419  1298.605287      613.862366          2651.396454
#
#    Salinity (%)
# 0      0.220000
# 1      0.360000
# 2      1.039793
# 3      1.772764
# 4      1.427913

# %%
df.tail()
# Out:
#         Date  Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)  \
# 38  03/03/25      364.491290  2030.813871      966.401936
# 39  03/04/25      328.093000  2798.267333     1345.957667
# 40  03/05/25      242.210968  1973.634091      949.288182
# 41       NaN             NaN          NaN             NaN
# 42       NaN             NaN          NaN             NaN
#
#     Conductivity(ms/cm)  Salinity (%)
# 38          3685.853548      2.082190
# 39          4998.816000      2.866310
# 40          3584.377273      1.995273
# 41                  NaN           NaN
# 42                  NaN           NaN

# %%
df.dtypes
# Out:
# Date                    object
# Turbidity(NTU)         float64
# TDS(mg/l)              float64
# Chloride(mg/L)         float64
# Conductivity(ms/cm)    float64
# Salinity (%)           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 41 non-null     object
#  1   Turbidity(NTU)       41 non-null     float64
#  2   TDS(mg/l)            41 non-null     float64
#  3   Chloride(mg/L)       41 non-null     float64
#  4   Conductivity(ms/cm)  41 non-null     float64
#  5   Salinity (%)         41 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 2.1+ KB

# %%
df.describe()#statical information about numerical column
# Out:
#        Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)  Conductivity(ms/cm)  \
# count       41.000000    41.000000       41.000000            41.000000
# mean       290.257467   861.888385      416.666594          1714.473305
# std        103.392096   727.895186      395.681946          1407.709180
# min        105.030000   129.110000       31.140000           268.650000
# 25%        198.430179   286.746237       80.866667           557.697312
# 50%        291.464731   577.243908      250.334483          1177.206322
# 75%        364.491290  1463.191419      764.112698          2985.519922
# max        502.135333  2798.267333     1345.957667          4998.816000
#
#        Salinity (%)
# count     41.000000
# mean       0.945576
# std        0.774344
# min        0.130000
# 25%        0.342900
# 50%        0.636259
# 75%        1.591691
# max        2.866310

# %% [raw]
# DATA --> 1. numerical(quantitative data) --> 1.1 continuous(343234.65),1.2 Discrete(whole number,like how many children so ans is whole 2 or 3(int))
#          2. categorical(qualitative data)

# %%
#five point summary >> min, 25%, 50%, 75%, max

# %%
df[[	"Turbidity(NTU)",	"TDS(mg/l)",	"Chloride(mg/L)"	]]
# Out:
#     Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)
# 0       156.830000   183.570000       52.270000
# 1       270.929286   310.823095      138.734524
# 2       341.769032   950.239737      441.344762
# 3       502.135333  1583.427146      691.952778
# 4       432.117419  1298.605287      613.862366
# 5       356.187333  1060.554114      496.920000
# 6       319.416129   879.429677      444.374839
# 7       415.629416   457.040399      212.974270
# 8       409.616667   200.686667       60.670000
# 9       299.942857   208.250000       68.357143
# 10      348.553333   301.583333      110.783333
# 11      313.691398   330.516129      117.080645
# 12      273.009140   389.220430      139.559140
# 13      432.070833   796.419643      378.523810
# 14      439.493637  1575.146806      827.199817
# 15      397.762960  1671.016855      871.147359
# 16      422.904957  1857.135165      974.667293
# 17      266.990520  1463.191419      771.949787
# 18      283.340591   792.983781      389.590771
# ...

# %%
df.dtypes
# Out:
# Date                    object
# Turbidity(NTU)         float64
# TDS(mg/l)              float64
# Chloride(mg/L)         float64
# Conductivity(ms/cm)    float64
# Salinity (%)           float64
# dtype: object

# %%
df.dtypes == "object" #object is a string datatypes
# Out:
# Date                    True
# Turbidity(NTU)         False
# TDS(mg/l)              False
# Chloride(mg/L)         False
# Conductivity(ms/cm)    False
# Salinity (%)           False
# dtype: bool

# %%
df.dtypes == "float"
# Out:
# Date                   False
# Turbidity(NTU)          True
# TDS(mg/l)               True
# Chloride(mg/L)          True
# Conductivity(ms/cm)     True
# Salinity (%)            True
# dtype: bool

# %%
df.dtypes[df.dtypes == "float"]
#return those series value where the condition is true
# Out:
# Turbidity(NTU)         float64
# TDS(mg/l)              float64
# Chloride(mg/L)         float64
# Conductivity(ms/cm)    float64
# Salinity (%)           float64
# dtype: object

# %%
#To get the index

# %%
df.dtypes[df.dtypes == "object"].index
# Out:
# Index(['Date'], dtype='object')

# %%
#the string data
df[df.dtypes[df.dtypes == "object"].index]
# Out:
#         Date
# 0   03/01/22
# 1   03/02/22
# 2   03/03/22
# 3   03/04/22
# 4   03/05/22
# 5   03/06/22
# 6   03/07/22
# 7   03/08/22
# 8   03/09/22
# 9   03/10/22
# 10  03/11/22
# 11  03/12/22
# 12  03/01/23
# 13  03/02/23
# 14  03/03/23
# 15  03/04/23
# 16  03/05/23
# 17  03/06/23
# 18  03/07/23
# 19  03/08/23
# 20  03/09/23
# 21  03/10/23
# 22  03/11/23
# 23  03/12/23
# 24  03/01/24
# 25  03/02/24
# 26  03/03/24
# 27  03/04/24
# 28  03/05/24
# 29  03/06/24
# 30  03/07/24
# 31  03/08/24
# 32  03/09/24
# 33  03/10/24
# 34  03/11/24
# 35  03/12/24
# 36  03/01/25
# 37  03/02/25
# 38  03/03/25
# 39  03/04/25
# 40  03/05/25
# 41       NaN
# 42       NaN

# %%
#numercail data
df[df.dtypes[df.dtypes != "object"].index].describe()
# Out:
#        Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)  Conductivity(ms/cm)  \
# count       41.000000    41.000000       41.000000            41.000000
# mean       290.257467   861.888385      416.666594          1714.473305
# std        103.392096   727.895186      395.681946          1407.709180
# min        105.030000   129.110000       31.140000           268.650000
# 25%        198.430179   286.746237       80.866667           557.697312
# 50%        291.464731   577.243908      250.334483          1177.206322
# 75%        364.491290  1463.191419      764.112698          2985.519922
# max        502.135333  2798.267333     1345.957667          4998.816000
#
#        Salinity (%)
# count     41.000000
# mean       0.945576
# std        0.774344
# min        0.130000
# 25%        0.342900
# 50%        0.636259
# 75%        1.591691
# max        2.866310

# %%
df.describe()
# Out:
#        Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)  Conductivity(ms/cm)  \
# count       41.000000    41.000000       41.000000            41.000000
# mean       290.257467   861.888385      416.666594          1714.473305
# std        103.392096   727.895186      395.681946          1407.709180
# min        105.030000   129.110000       31.140000           268.650000
# 25%        198.430179   286.746237       80.866667           557.697312
# 50%        291.464731   577.243908      250.334483          1177.206322
# 75%        364.491290  1463.191419      764.112698          2985.519922
# max        502.135333  2798.267333     1345.957667          4998.816000
#
#        Salinity (%)
# count     41.000000
# mean       0.945576
# std        0.774344
# min        0.130000
# 25%        0.342900
# 50%        0.636259
# 75%        1.591691
# max        2.866310

# %%
df.describe(include = "object")
# Out:
#             Date
# count         41
# unique        41
# top     03/01/22
# freq           1

# %%
df.describe(include = "float")
# Out:
#        Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)  Conductivity(ms/cm)  \
# count       41.000000    41.000000       41.000000            41.000000
# mean       290.257467   861.888385      416.666594          1714.473305
# std        103.392096   727.895186      395.681946          1407.709180
# min        105.030000   129.110000       31.140000           268.650000
# 25%        198.430179   286.746237       80.866667           557.697312
# 50%        291.464731   577.243908      250.334483          1177.206322
# 75%        364.491290  1463.191419      764.112698          2985.519922
# max        502.135333  2798.267333     1345.957667          4998.816000
#
#        Salinity (%)
# count     41.000000
# mean       0.945576
# std        0.774344
# min        0.130000
# 25%        0.342900
# 50%        0.636259
# 75%        1.591691
# max        2.866310

# %%
df.describe(include = "all")
# Out:
#             Date  Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)  \
# count         41       41.000000    41.000000       41.000000
# unique        41             NaN          NaN             NaN
# top     03/01/22             NaN          NaN             NaN
# freq           1             NaN          NaN             NaN
# mean         NaN      290.257467   861.888385      416.666594
# std          NaN      103.392096   727.895186      395.681946
# min          NaN      105.030000   129.110000       31.140000
# 25%          NaN      198.430179   286.746237       80.866667
# 50%          NaN      291.464731   577.243908      250.334483
# 75%          NaN      364.491290  1463.191419      764.112698
# max          NaN      502.135333  2798.267333     1345.957667
#
#         Conductivity(ms/cm)  Salinity (%)
# count             41.000000     41.000000
# unique                  NaN           NaN
# top                     NaN           NaN
# freq                    NaN           NaN
# ...

# %%
df.astype('object').describe()#gives the statical information considering categorical  column
# Out:
#             Date  Turbidity(NTU)  TDS(mg/l)  Chloride(mg/L)  \
# count         41           41.00      41.00           41.00
# unique        41           41.00      41.00           41.00
# top     03/01/22          156.83     183.57           52.27
# freq           1            1.00       1.00            1.00
#
#         Conductivity(ms/cm)  Salinity (%)
# count                 41.00         41.00
# unique                41.00         41.00
# top                  375.37          0.22
# freq                   1.00          1.00

# %%
df.shape
# Out:
# (43, 6)

# %%
df[0:39] # [start:end-1:Step] size
# Out:
#         Date  Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)  \
# 0   03/01/22      156.830000   183.570000       52.270000
# 1   03/02/22      270.929286   310.823095      138.734524
# 2   03/03/22      341.769032   950.239737      441.344762
# 3   03/04/22      502.135333  1583.427146      691.952778
# 4   03/05/22      432.117419  1298.605287      613.862366
# 5   03/06/22      356.187333  1060.554114      496.920000
# 6   03/07/22      319.416129   879.429677      444.374839
# 7   03/08/22      415.629416   457.040399      212.974270
# 8   03/09/22      409.616667   200.686667       60.670000
# 9   03/10/22      299.942857   208.250000       68.357143
# 10  03/11/22      348.553333   301.583333      110.783333
# 11  03/12/22      313.691398   330.516129      117.080645
# 12  03/01/23      273.009140   389.220430      139.559140
# 13  03/02/23      432.070833   796.419643      378.523810
# 14  03/03/23      439.493637  1575.146806      827.199817
# ...

# %%
df[0:39:5]
# Out:
#         Date  Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)  \
# 0   03/01/22      156.830000   183.570000       52.270000
# 5   03/06/22      356.187333  1060.554114      496.920000
# 10  03/11/22      348.553333   301.583333      110.783333
# 15  03/04/23      397.762960  1671.016855      871.147359
# 20  03/09/23      275.326000   295.003333      115.365000
# 25  03/02/24      235.926379   577.243908      250.334483
# 30  03/07/24      210.984773   690.112865      363.848310
# 35  03/12/24      105.030000   255.540000       66.400000
#
#     Conductivity(ms/cm)  Salinity (%)
# 0            375.370000      0.220000
# 5           2163.357619      1.165638
# 10           615.500000      0.347167
# 15          3396.765229      1.849917
# 20           601.281667      0.342900
# 25          1177.206322      0.636259
# 30          1407.579339      0.762670
# 35           520.050000      0.250000

# %%
df
df["Level"] = "Moderate"

# %%
df
# Out:
#         Date  Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)  \
# 0   03/01/22      156.830000   183.570000       52.270000
# 1   03/02/22      270.929286   310.823095      138.734524
# 2   03/03/22      341.769032   950.239737      441.344762
# 3   03/04/22      502.135333  1583.427146      691.952778
# 4   03/05/22      432.117419  1298.605287      613.862366
# 5   03/06/22      356.187333  1060.554114      496.920000
# 6   03/07/22      319.416129   879.429677      444.374839
# 7   03/08/22      415.629416   457.040399      212.974270
# 8   03/09/22      409.616667   200.686667       60.670000
# 9   03/10/22      299.942857   208.250000       68.357143
# 10  03/11/22      348.553333   301.583333      110.783333
# 11  03/12/22      313.691398   330.516129      117.080645
# 12  03/01/23      273.009140   389.220430      139.559140
# 13  03/02/23      432.070833   796.419643      378.523810
# 14  03/03/23      439.493637  1575.146806      827.199817
# ...

# %%
#create  new column in existing column
df["Turbidity+TDS"] = df["Turbidity(NTU)"]+df["TDS(mg/l)"]

# %%
df
# Out:
#         Date  Turbidity(NTU)    TDS(mg/l)  Chloride(mg/L)  \
# 0   03/01/22      156.830000   183.570000       52.270000
# 1   03/02/22      270.929286   310.823095      138.734524
# 2   03/03/22      341.769032   950.239737      441.344762
# 3   03/04/22      502.135333  1583.427146      691.952778
# 4   03/05/22      432.117419  1298.605287      613.862366
# 5   03/06/22      356.187333  1060.554114      496.920000
# 6   03/07/22      319.416129   879.429677      444.374839
# 7   03/08/22      415.629416   457.040399      212.974270
# 8   03/09/22      409.616667   200.686667       60.670000
# 9   03/10/22      299.942857   208.250000       68.357143
# 10  03/11/22      348.553333   301.583333      110.783333
# 11  03/12/22      313.691398   330.516129      117.080645
# 12  03/01/23      273.009140   389.220430      139.559140
# 13  03/02/23      432.070833   796.419643      378.523810
# 14  03/03/23      439.493637  1575.146806      827.199817
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 41 non-null     object
#  1   Turbidity(NTU)       41 non-null     float64
#  2   TDS(mg/l)            41 non-null     float64
#  3   Chloride(mg/L)       41 non-null     float64
#  4   Conductivity(ms/cm)  41 non-null     float64
#  5   Salinity (%)         41 non-null     float64
#  6   new col              43 non-null     object
#  7   Level                43 non-null     object
#  8   Turbidity+TDS        41 non-null     float64
# dtypes: float64(6), object(3)
# memory usage: 3.2+ KB

# %%
pd.Categorical(df["TDS(mg/l)"])#Diff categories of TDS
# Out:
# [183.570000, 310.823095, 950.239737, 1583.427146, 1298.605287, ..., 2030.813871, 2798.267333, 1973.634091, NaN, NaN]
# Length: 43
# Categories (41, float64): [129.110000, 140.820000, 159.844355, 171.108602, ..., 2030.813871, 2051.474259, 2309.939337, 2798.267333]

# %%
df["TDS(mg/l)"].unique()
# Out:
# array([ 183.57     ,  310.8230952,  950.2397372, 1583.427146 ,
#        1298.605287 , 1060.554114 ,  879.4296774,  457.0403994,
#         200.6866667,  208.25     ,  301.5833333,  330.516129 ,
#         389.2204301,  796.4196429, 1575.146806 , 1671.016855 ,
#        1857.135165 , 1463.191419 ,  792.9837814,  496.6961111,
#         295.0033333,  171.1086022,  312.2727778,  261.333871 ,
#         325.3903226,  577.243908 , 1566.491039 , 2051.474259 ,
#        2309.939337 , 1313.651786 ,  690.1128648,  159.8443548,
#         129.11     ,  140.82     ,  178.3      ,  255.54     ,
#         286.7462366,  703.79     , 2030.813871 , 2798.267333 ,
#        1973.634091 ,          nan])

# %%
df["Salinity (%)"].unique()
# Out:
# array([0.22      , 0.36      , 1.03979274, 1.77276446, 1.42791308,
#        1.1656377 , 0.97      , 0.51328264, 0.24523333, 0.25321429,
#        0.34716667, 0.37263441, 0.43782258, 0.87684524, 1.7443445 ,
#        1.84991668, 2.05803652, 1.59169149, 0.87093548, 0.55981111,
#        0.3429    , 0.21844624, 0.36072778, 0.30625269, 0.3711129 ,
#        0.63625862, 1.7407957 , 2.28563611, 2.58408026, 1.4496369 ,
#        0.76267012, 0.18348656, 0.13      , 0.14      , 0.18      ,
#        0.25      , 0.50844624, 0.69735   , 2.08219032, 2.86631   ,
#        1.99527273,        nan])

# %%
df["Salinity (%)"].nunique()
#no of unique value
# Out:
# 41

# %%
df["Salinity (%)"].value_counts()
# Out:
# Salinity (%)
# 0.220000    1
# 0.218446    1
# 0.306253    1
# 0.371113    1
# 0.636259    1
# 1.740796    1
# 2.285636    1
# 2.584080    1
# 1.449637    1
# 0.762670    1
# 0.183487    1
# 0.130000    1
# 0.140000    1
# 0.180000    1
# 0.250000    1
# 0.508446    1
# 0.697350    1
# 2.082190    1
# 2.866310    1
# 0.360728    1
# 0.342900    1
# 0.360000    1
# 0.559811    1
# 1.039793    1
# 1.772764    1
# 1.427913    1
# 1.165638    1
# 0.970000    1
# 0.513283    1
# 0.245233    1
# 0.253214    1
# 0.347167    1
# 0.372634    1
# 0.437823    1
# 0.876845    1
# 1.744344    1
# 1.849917    1
# 2.058037    1
# 1.591691    1
# 0.870935    1
# 1.995273    1
# Name: count, dtype: int64

# %%
#how many value less than 200
len(df[df['TDS(mg/l)']<200])
# Out:
# 6

# %%
len(df[df['TDS(mg/l)']>=200])
# Out:
# 35

# %%
#Q. How many vlaue less than avg TDS?

# %%
df['TDS(mg/l)'].mean()
# Out:
# np.float64(861.8883849463414)

# %%
len(df['TDS(mg/l)']< 861.88)
# Out:
# 43

# %%
len(df['TDS(mg/l)'] < df['TDS(mg/l)'].mean())
# Out:
# 43

# %%
#how many value have 0 value
len(df[df['TDS(mg/l)'] == 0])
# Out:
# 0

# %%
df["TDS(mg/l)"].value_counts(normalize = True)
# Out:
# TDS(mg/l)
# 183.570000     0.02439
# 171.108602     0.02439
# 261.333871     0.02439
# 325.390323     0.02439
# 577.243908     0.02439
# 1566.491039    0.02439
# 2051.474259    0.02439
# 2309.939337    0.02439
# 1313.651786    0.02439
# 690.112865     0.02439
# 159.844355     0.02439
# 129.110000     0.02439
# 140.820000     0.02439
# 178.300000     0.02439
# 255.540000     0.02439
# 286.746237     0.02439
# 703.790000     0.02439
# 2030.813871    0.02439
# 2798.267333    0.02439
# 312.272778     0.02439
# 295.003333     0.02439
# 310.823095     0.02439
# 496.696111     0.02439
# 950.239737     0.02439
# 1583.427146    0.02439
# 1298.605287    0.02439
# 1060.554114    0.02439
# 879.429677     0.02439
# 457.040399     0.02439
# 200.686667     0.02439
# 208.250000     0.02439
# 301.583333     0.02439
# 330.516129     0.02439
# 389.220430     0.02439
# 796.419643     0.02439
# 1575.146806    0.02439
# 1671.016855    0.02439
# 1857.135165    0.02439
# 1463.191419    0.02439
# ...

# %%
#How many value near to TDS 1000

# %%
len(df[df["TDS(mg/l)"] >= 100])
# Out:
# 41

# %%
#how many TDS more than avg TDS

# %%
df["TDS(mg/l)"].mean()
# Out:
# np.float64(861.8883849463414)

# %%
df[(df["TDS(mg/l)"] => 500) & (500 > df["TDS(mg/l)"].mean())]
# Out:
#   Cell In[201], line 1
#     df[(df["TDS(mg/l)"] => 500) & (500 > df["TDS(mg/l)"].mean())]
#                         ^
# SyntaxError: invalid syntax

# %%
import numpy as np
np.mean(df["TDS(mg/l)"])
# Out:
# np.float64(861.8883849463414)

# %%
max(df['TDS(mg/l)'])
# Out:
# 2798.267333

# %%
min(df['TDS(mg/l)'])
# Out:
# 129.11

# %%
#Value has maximunm TDS

# %%
df[df["TDS(mg/l)"] == max(df["TDS(mg/l)"])].Date
# Out:
# 0     03/01/22
# 1     03/02/22
# 2     03/03/22
# 3     03/04/22
# 4     03/05/22
# 5     03/06/22
# 6     03/07/22
# 7     03/08/22
# 8     03/09/22
# 9     03/10/22
# 10    03/11/22
# 11    03/12/22
# 12    03/01/23
# 13    03/02/23
# 14    03/03/23
# 15    03/04/23
# 16    03/05/23
# 17    03/06/23
# 18    03/07/23
# 19    03/08/23
# 20    03/09/23
# 21    03/10/23
# 22    03/11/23
# 23    03/12/23
# 24    03/01/24
# 25    03/02/24
# 26    03/03/24
# 27    03/04/24
# 28    03/05/24
# 29    03/06/24
# 30    03/07/24
# 31    03/08/24
# 32    03/09/24
# 33    03/10/24
# 34    03/11/24
# 35    03/12/24
# 36    03/01/25
# 37    03/02/25
# 38    03/03/25
# 39    03/04/25
# 40    03/05/25
# 41         NaN
# 42         NaN
# Name: Date, dtype: object
