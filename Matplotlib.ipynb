# %%
#matplotlib and seaborn is most important visualization tools in machine learning
#Which graph used where 

#why do we need visualization >> Summarisation of data
#Matplotlib,seaborn, plotly, bokeh
#matplotlib >> Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")#suppress all warnings

# %%
#line,scatter, bar, histogram, pie, box,violin plot

# %%
#generate random numbers in numpy

# %%
x = np.random.rand(50)

# %%
len(x)
# Out:
# 50

# %%
np.random.randn(50)
# Out:
# array([-0.18127643,  0.85803812, -0.04168689, -1.34601791, -1.32384992,
#        -2.50011782, -0.11757095, -0.67226177, -0.02294978,  1.00991199,
#         1.47047441,  0.87603702, -1.55526637, -2.19233078,  0.69756256,
#        -0.82342485, -0.43606702, -0.30875909, -1.17501802,  1.50240474,
#         0.11572474, -1.1470429 ,  0.14224986,  0.77369907, -0.33960962,
#         2.12648917,  0.17346385, -0.0214436 , -1.70106466, -1.94491774,
#        -1.65321285,  0.60992126, -0.61060225,  1.2355365 ,  0.78002542,
#         0.8609425 ,  0.76032569,  2.15229998, -0.56393101, -0.51041082,
#         1.77378322,  0.2404945 ,  0.38436869,  0.92611739,  0.81963236,
#        -0.55400452, -0.58794025, -1.16393992, -0.71256692, -0.19797012])

# %%
df = pd.DataFrame(np.random.randn(1000),columns = ['Data'],index = pd.date_range('2024-07-11', periods = 1000))

# %%
df
# Out:
#                 Data
# 2024-07-11 -2.561858
# 2024-07-12  0.111031
# 2024-07-13 -0.736509
# 2024-07-14  1.121311
# 2024-07-15 -0.232810
# ...              ...
# 2027-04-02 -1.082457
# 2027-04-03  1.052946
# 2027-04-04 -0.332385
# 2027-04-05 -0.610822
# 2027-04-06 -0.129369
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (20,8)) #summary >> most of the values are fluctuatting between - 2 and 2
# Out:
# <Axes: >

# %%
x
# Out:
# array([0.22477024, 0.18458446, 0.22548387, 0.42172402, 0.16212319,
#        0.31875903, 0.23217578, 0.52086097, 0.46383931, 0.89083998,
#        0.67776036, 0.67396025, 0.40146693, 0.83294024, 0.17469206,
#        0.11307172, 0.64903484, 0.02884894, 0.39609226, 0.35603228,
#        0.2608214 , 0.97482057, 0.59598135, 0.06919804, 0.68077847,
#        0.41399332, 0.74668795, 0.72693612, 0.29779508, 0.0097738 ,
#        0.38919866, 0.98390785, 0.2165377 , 0.29668954, 0.75661595,
#        0.37773028, 0.10456678, 0.07040433, 0.92679676, 0.93908112,
#        0.48070107, 0.82224085, 0.93097789, 0.73991395, 0.12329309,
#        0.75075865, 0.22733464, 0.02582844, 0.77249827, 0.85620118])

# %%
y =np.random.rand(50)

# %%
y
# Out:
# array([0.47573025, 0.55124216, 0.6169359 , 0.60879478, 0.38366621,
#        0.81197318, 0.81509536, 0.42668167, 0.63084678, 0.67386561,
#        0.78137639, 0.57980558, 0.78121197, 0.26349484, 0.42449252,
#        0.13960101, 0.09866986, 0.27427804, 0.73833557, 0.32173336,
#        0.43805127, 0.13543987, 0.57791845, 0.89016491, 0.89039312,
#        0.07857735, 0.10511289, 0.00876625, 0.14787584, 0.85196844,
#        0.35431438, 0.59579812, 0.67301159, 0.55606941, 0.56876232,
#        0.08417364, 0.71352114, 0.51638462, 0.73102831, 0.5131637 ,
#        0.26489161, 0.91332936, 0.55379074, 0.9583458 , 0.79022861,
#        0.07531043, 0.78788133, 0.20016956, 0.83544613, 0.61167425])

# %%
#scatter plot >> Relationship b/w two value in cartisian plane
plt.scatter(x,y)

# %%
#line plot
#whenever you want to depict the relation between two variables in the form of trend
#mostly in x axis the date-time column is there
x=[1,2,3,4,5]#x assumed no of days
y=[5,2,7,8,1]#y is proce of stock

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
y
# Out:
# [5, 2, 7, 8, 1]

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.title("Line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y, color = "red")
plt.title("Line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y, color = "red", marker = "o")
plt.title("Line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y, color = "red", marker = "o", linestyle = "dashdot")
plt.title("Line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y, color = "red", marker = "o", linestyle = "dashdot",linewidth = 4)
plt.title("Line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y, color = "red", marker = "o", linestyle = "dashdot",linewidth = 4,markersize= 15)
plt.title("Line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y, color = "red", marker = "o", linestyle = "dashdot",linewidth = 4,markersize= 15)
plt.title("Line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.grid()
plt.show()

# %%
x = [1,2,3,4,5]
y1 = [5,1,7,8,2]
y2 = [7,8,3,5,1]

plt.plot(x,y1, color = "red", marker = "o", linestyle = "dashdot",linewidth = 3, markersize = 5, label = "line y1")

# %%
x = [1,2,3,4,5]
y1 = [5,1,7,8,2]
y2 = [7,8,3,5,1]

plt.plot(x, y1, color = 'red', marker = 'o', linestyle ='dashdot', linewidth = 3, markersize = 6 , label = "line y1 as tata motors")
plt.plot(x, y2, color = 'b', marker = 'o', linestyle ='dashdot', linewidth = 3, markersize = 6 , label = "line y2 tata power")
plt.title("Multiple lines in one plot")
plt.xlabel("Days")
plt.ylabel("Stock price")
plt.legend()
plt.show()

# %%
x = np.linspace(0,10,100)

# %%
plt.plot(x,np.sin(x))
plt.plot(x, np.cos(x))
plt.show()

# %%
plt.plot(x,np.sin(x),linestyle = "dashdot")
plt.show()

# %%
plt.plot(x,np.sin(x),linestyle = "dashed")

# %%
plt.plot(x,np.sin(x),linestyle = "solid")

# %%
plt.figure()#initialising a page to make plot
plt.subplot(2,1,1)
plt.plot(x, np.sin(x))

plt.subplot(2,1,2)
plt.plot(x, np.cos(x))

plt.show()

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x, np.sin(x))

plt.subplot(2,2,2)
plt.plot(x, np.cos(x))

plt.subplot(2,2,3)
plt.plot(x, np.tan(x))

plt.subplot(2,2,4)
plt.plot(x, np.sin(x+1))

plt.show()

# %%
plt.plot(x, np.sin(x-0), color = "Blue")
plt.ylim(-1.5,1.5)
plt.xlim(1,15) #the range has been changed
# Out:
# (1.0, 15.0)

# %%
plt.plot(x, np.sin(x-0), color = "Blue")
plt.ylim(-1.5,1.5)
plt.xlim(1,15) 
plt.axis('equal')
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = "Blue")
plt.ylim(-1.5,1.5)
plt.xlim(1,15) 
plt.axis('equal')
plt.grid()
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = "Blue")
plt.ylim(-1.5,1.5)
plt.xlim(1,15) 
plt.title("basic syntax")
plt.xlabel("x lable")
plt.ylabel("y label")
plt.axis('equal')
plt.grid()
plt.show()

# %%
#how to make a histograme>> continuous numerical data
#Numerical >>1. continuous 2. discrete

data = np.random.rand(1000) # by default 10 bins are created
plt.hist(data)
plt.show()

# %%
# divide data into 10 intervals(bins)
data = np.random.rand(1000) # by default 10 bins are created
plt.hist(data, color = 'r', bins = 20)
plt.show()

# %%
#stacked histogram>>two histograms together
data1 = np.random.normal(0,1,5000)
data2 = np.random.normal(3,2,5000)

# %%
data1
# Out:
# array([-0.24323156,  0.7049673 ,  0.09890484, ..., -0.63758468,
#         0.56473271, -0.60351264], shape=(5000,))

# %%
data2
# Out:
# array([1.95048556, 2.4488778 , 0.87922488, ..., 0.0202648 , 2.38015327,
#        1.23390496], shape=(5000,))

# %%
plt.hist([data1,data2],bins=20, color =['r','b'])
plt.xlabel("Value")
plt.ylabel("frequency")
plt.title("Stacked Histogram")
plt.show()

# %%
#scatterplot >> to understand relationship between two features
x = np.random.rand(50)
y = np.random.rand(50)

# %%
x
# Out:
# array([5.17904262e-01, 9.34636299e-01, 2.87819779e-02, 2.67691612e-01,
#        9.73950168e-01, 9.16908245e-04, 5.50284325e-01, 8.15327123e-01,
#        2.43493171e-01, 5.13890798e-01, 2.16337604e-01, 7.69298231e-01,
#        8.10163209e-01, 9.58838399e-01, 1.36026546e-01, 5.63253980e-01,
#        8.27621800e-01, 5.96993681e-02, 4.43111405e-01, 7.09854558e-01,
#        5.95143764e-01, 9.18430880e-01, 6.11241212e-01, 1.78398237e-01,
#        6.38972179e-01, 9.90645865e-02, 6.45365508e-01, 8.47997312e-01,
#        8.96540364e-01, 1.43741333e-01, 3.89677110e-01, 2.47876795e-01,
#        4.46399590e-01, 5.72972391e-02, 8.00737888e-02, 2.86644409e-01,
#        6.56676299e-01, 2.03804394e-01, 1.01682766e-01, 6.07212957e-01,
#        8.16955271e-01, 9.78835976e-01, 8.19927061e-01, 8.46073002e-01,
#        8.32399779e-01, 6.61054331e-01, 9.12378004e-01, 6.19393272e-01,
#        2.16216147e-01, 7.56710648e-01])

# %%
y
# Out:
# array([0.66176301, 0.89527146, 0.89799325, 0.36212071, 0.41101335,
#        0.10586743, 0.69400259, 0.23398652, 0.89784043, 0.73736126,
#        0.0769023 , 0.9289778 , 0.00427081, 0.76360864, 0.86150635,
#        0.01636965, 0.53136516, 0.20849132, 0.23308297, 0.23716007,
#        0.27673414, 0.38543551, 0.93846133, 0.41940832, 0.2537935 ,
#        0.23757827, 0.34888328, 0.40325227, 0.52443877, 0.39383679,
#        0.37524803, 0.60900241, 0.79058522, 0.70740739, 0.53739235,
#        0.79418468, 0.16659963, 0.55651695, 0.24188761, 0.12793714,
#        0.20947754, 0.4052847 , 0.74062054, 0.88193789, 0.80212426,
#        0.91123585, 0.82729678, 0.95689522, 0.116094  , 0.63584271])

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.scatter(x,y, c='r', marker = 'X')
plt.show()

# %%
#bar plot >> To see the distribution of categorical variables
x = ['a', 'b', 'c', 'd'] #name of students 
y = [4,6,1,10] #number of days present in the Class
plt.bar(x,y,color ='b')#vertical plot
# Out:
# <BarContainer object of 4 artists>

# %%
#bar plot >> To see the distribution of categorical variables
x = ['a', 'b', 'c', 'd'] #name of students 
y = [4,6,1,10] #number of days present in the Class
plt.barh(x,y,color ='b')#horizontal plot
plt.show()

# %%
#pie chart use to under stand the percentage distribution of data
langs = ["c","python","java"]
students = [20,100,40]

plt.pie(students,labels = langs, autopct = "%1.1f%%")
plt.title("P")
plt.show()

# %%
#focus on one segment
explode = (0.0,0.1,0.1)
langs = ["c","python","java"]
students = [20,100,40]
plt.pie(students,labels = langs, autopct = "%1.1f%%",explode = explode)
plt.title("Pie chart")
plt.show()

# %%
explode = (0.0,0.05,0.05)
langs = ["c","python","java"]
students = [20,100,40]
plt.pie(students,labels = langs, autopct = "%1.1f%%",explode = explode, shadow = True)
plt.title("Pie chart")
plt.show()

# %%
# 3d plot
x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection = "3d")
ax.scatter(x,y,z,c="r")
plt.show()

# %%
data = pd.read_csv("all data 22jan to 25jan.csv")

# %%
data
# Out:
#            Date  River Turbidity(NTU)  River TDS(mg/l)  River Chloride(mg/L)  \
# 0     01-Jan-22                 76.50           152.00                 40.00
# 1     02-Jan-22                155.00           160.00                 40.00
# 2     03-Jan-22                178.00           157.00                 40.00
# 3     04-Jan-22                218.00           191.00                 58.00
# 4     05-Jan-22                272.00           230.00                 84.00
# ...         ...                   ...              ...                   ...
# 999   27-Jan-25                 43.24           219.00                 43.20
# 1000  28-Jan-25                 70.10           223.80                 45.80
# 1001  29-Jan-25                106.50           244.00                 53.50
# 1002  30-Jan-25                175.75           352.75                109.75
# 1003  31-Jan-25                257.00           693.60                292.60
#
# ...

# %%
plt.scatter(x=data["River Turbidity(NTU)"], y =data["Treated Turbidity(NTU)"])

# %%
data.plot.scatter(x= 'River Turbidity(NTU)', y = "Treated Turbidity(NTU)")
# Out:
# <Axes: xlabel='River Turbidity(NTU)', ylabel='Treated Turbidity(NTU)'>

# %%
plt.hist(data["River Turbidity(NTU)"], color = 'red')
# Out:
# (array([174., 249., 184., 142.,  82.,  77.,  43.,  25.,  14.,   5.]),
#  array([ 38.675 , 133.9075, 229.14  , 324.3725, 419.605 , 514.8375,
#         610.07  , 705.3025, 800.535 , 895.7675, 991.    ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data["Treated Turbidity(NTU)"], color = 'b')
# Out:
# (array([109., 206., 261., 207., 161.,  33.,  15.,   6.,   1.,   4.]),
#  array([ 0.62 ,  1.646,  2.672,  3.698,  4.724,  5.75 ,  6.776,  7.802,
#          8.828,  9.854, 10.88 ]),
#  <BarContainer object of 10 artists>)

# %%
#Boxplot   >> to check the distribution of data and outliers(extream/abnormal value)
data.boxplot(column =  "Treated Turbidity(NTU)") #upper line is >> upper fence
#lower line is >> lower fence
#last one is quartile 1(Q1) then median is Q2 and then Q3
# Out:
# <Axes: >

# %%
plt.violinplot(data["Treated Turbidity(NTU)"]) >> variation
plt.show()

# %%
#Area plot >> variables changed over time
#An area chart is a visual representation of data that utilizes both lines and filled areas to convey information. 
#This type of chart is particularly effective in showcasing data trends and variations over a specified period 
#or across different categories.

# %%
years = [2021,2018,2022,2023,2017]
category1 = [20,25,30,28,35]
category2 = [10,15,20,18,25]
category3 = [5,8,10,9,15]

# %%
plt.stackplot(years, category1,category2,category3, labels = ["category1","category2","category3"],colors = ['skyblue','lightgreen','orange'])
plt.xlabel("years")
plt.ylabel("Values")
plt.title("Area plot")
plt.legend()
plt.show()
